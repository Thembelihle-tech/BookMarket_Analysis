# %%
import time
import re
import requests 
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

sns.set_style("whitegrid")
plt.rcParams["figure.figsize"] = (9, 5)

BASE_URL = "https://books.toscrape.com/"
CATALOGUE_URL = BASE_URL + "catalogue/"
HEADERS = {"User-Agent": "Mozilla/5.0 (Scraper)"}

RATING_WORDS = {"One": 1, "Two": 2, "Three": 3, "Four": 4, "Five": 5}

# %% [markdown]
# ## 1: Data Acquisition

# %%
def get_group(url):
    """Fetch a URL and return a BeautifulSoup obect."""
    response = requests.get(url, headers=HEADERS)
    response.raise_for_status()
    return BeautifulSoup(response.text, "html.parser")

def parse_stock(stock_text):
    """Extract availability status and quantity from stock text."""
    stock_text = stock_text.strip()
    in_stock = "In stock" in stock_text
    match = re.search(r"\((\d+) available\)", stock_text)
    quantity = int(match.group(1)) if match else None
    return ("In stock" if in_stock else "Out of stock"), quantity

def scrape_listing_page(page_num):
    """Scrape one catalogue listing page, return list of book dicts."""
    url = CATALOGUE_URL + f"page-{page_num}.html"
    try:
        soup = get_group(url)
    except requests.exceptions.HTTPError:
        return [] #no more pages
    books = soup.select("article.product_pod")
    results = []

    for book in books:
        title = book.h3.a["title"]
        price_text = book.select_one(".price_color").text.strip()
        price = float(re.sub(r"[^\d.]", "", price_text))

        rating_word = book.select_one(".star-rating")["class"][1]
        rating_num = RATING_WORDS.get(rating_word)
        relative_href = book.h3.a["href"]
        detail_url = CATALOGUE_URL + relative_href.replace("../../../", "")

        results.append({
            "title": title,
            "price_gbp": price,
            "rating_word": rating_word,
            "rating_num": rating_num,
            "detail_url": detail_url
        })
    return results

def scrape_books(min_books=200):
    """Loop through catalogue pages, visit each book's detail page for stock info."""
    all_books = []
    page = 1

    while len(all_books) < min_books:
        print(f"Scraping listing page {page}...")
        page_books = scrape_listing_page(page)
        if not page_books:
            print("No more pages found.")
            break

        for b in page_books:
            detail_soup = get_group(b["detail_url"])
            stock_text = detail_soup.select_one(".instock.availability").text
            status, quantity = parse_stock(stock_text)
            b["stock_status"] = status
            b["stock_quantity"] = quantity
            all_books.append(b)
            time.sleep(0.2)

        page +=1
    return all_books

raw_books = scrape_books(min_books=200)
df = pd.DataFrame(raw_books)
print(f"Collected {len(df)} books.")
print(df.head())

df.to_csv("books_raw.csv", index=False)
# Out:
# Scraping listing page 1...
